# %% [markdown]
# ## 문제 1 사각형 클래스 만들기

# %%
## 사각형 클래스 만들기

class Square:
    def __init__(self): 
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>')) 

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')

        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')

        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, height = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * height
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        width, height = map(int, input('밑변, 높이를 입력하세요. 예시 : 밑변,높이\n >>>').split(','))
        area = width * height
        result = '평형사변형의 넓이는 : ' + str(area)
        return result

    def trape(self):
        lower, upper, height = map(int, input('밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이\n >>>').split(','))
        area = (lower + upper) / 2 * height
        result = '사다리꼴의 넓이는 : ' + str(area)
        return result

# %%
a = Square()
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>> 3
# 사다리꼴 함수는 trape()입니다.

# %%
a.par()
# Out:
# 밑변, 높이를 입력하세요. 예시 : 밑변,높이
#  >>> 3,4
# '평형사변형의 넓이는 : 12'

# %%
a.trape()
# Out:
# 밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이
#  >>> 2,2,3
# '사다리꼴의 넓이는 : 6.0'

# %% [markdown]
# ## 문제 2 키오스크 1

# %%
## 메뉴판 출력하기

# 커피 메뉴와 가격
coffee = ['americano', 'latte', 'mocha']
c_price = [2000, 3000, 3000]

# 커피 이외의 메뉴와 가격
non_coffee = ['yuza_tea', 'green_tea', 'choco_latte']
n_price = [2500, 2500, 3000]

# 전체 메뉴 가격
menu = coffee + non_coffee
price = c_price + n_price
print(menu[3:], price[3:])
# Out:
# ['yuza_tea', 'green_tea', 'choco_latte'] [2500, 2500, 3000]

# %%
class Kiosk: 
    def __init__(self):
        # 문제 2-1의 답을 입력하세요. 
        self.menu = menu
        self.price = price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n & n <= len(menu):
                self.price_sum = self.price[n-1]  # 선택 음료의 가격
        
            # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

            if t == 1:
                self.temp = "HOT"
            elif t == 2:
                self.temp = 'ICE'
            else:    
                print("1과 2 중 하나를 입력하세요.\n")
        # 문제 2-2의 답을 입력하세요. 
        print('주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과 출력

# %%
# 아이스 초코라떼 주문해보기  
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료 번호를 입력하세요 :  5
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# 주문 음료 ICE green_tea : 2500 원

# %% [markdown]
# ### 추가 주문

# %%
class Kiosk: 
    def __init__(self):
        # 문제 2-1의 답을 입력하세요. 
        self.menu = menu
        self.price = price
        
        # 누적용
        self.price_sum = 0
        self.order_price = []
        self.order_menu = []

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        # 첫 주문
        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n & n <= len(self.menu):
                pass
                # self.price_sum = self.price[n-1]  # 선택 음료의 가격
        
            # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

            if t == 1:
                self.temp = "HOT"
            elif t == 2:
                self.temp = 'ICE'
            else:    
                print("1과 2 중 하나를 입력하세요.\n")
                
        # 문제 2-2의 답을 입력하세요. 
        self.order_menu.append(self.temp + ' ' + self.menu[n - 1])
        self.order_price.append(self.price[n - 1])
        self.price_sum += self.price[n - 1]
        print('주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과 출력

        # 추가 주문 또는 지불
        while n != 0: # 지불을 선택하기 전까지 반복하기
            print()
            n = int(input('추가 주문은 음료 번호를, 지불은 0을 누르세요: ')) # 추가주문 또는 지불
            if n > 0 and n < len(self.menu) + 1:
                # 추가 주문 음료 온도
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        self.temp = "HOT"
                    elif t == 2:
                        self.temp = "ICE"
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")


                self.order_price.append(self.price[n-1]) # 가격 리스트에 추가
                self.order_menu.append(self.temp + ' ' + self.menu[n-1]) # 주문 리스트에 추가
                self.price_sum += self.price[n-1] # 합계 금액

                print("추가주문 음료", self.temp, self.menu[n-1], ':', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')

            else:
                if n == 0:
                    print('주문이 완료되었습니다.')
                    # print(self.order_menu, self.order_price) # 확인을 위한 리스트 출력
                else:
                    print('없는 메뉴입니다.')

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료 번호를 입력하세요 :  6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  3
# 1과 2 중 하나를 입력하세요.
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# 주문 음료 ICE choco_latte : 3000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요:  2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  1
# 추가주문 음료 HOT latte : 3000 원
#  합계 :  6000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요:  0
# 주문이 완료되었습니다.

# %% [markdown]
# ## 문제 3 키오스크 2

# %%
class Kiosk: 
    def __init__(self):
        # 문제 2-1의 답을 입력하세요. 
        self.menu = menu
        self.price = price
        
        # 누적용
        self.price_sum = 0
        self.order_price = []
        self.order_menu = []

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        # 첫 주문
        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n & n <= len(self.menu):
                pass
                # self.price_sum = self.price[n-1]  # 선택 음료의 가격
        
            # 메뉴판에 없는 번호일 때
            else:  
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

            if t == 1:
                self.temp = "HOT"
            elif t == 2:
                self.temp = 'ICE'
            else:    
                print("1과 2 중 하나를 입력하세요.\n")
                
        # 문제 2-2의 답을 입력하세요. 
        self.order_menu.append(self.temp + ' ' + self.menu[n - 1])
        self.order_price.append(self.price[n - 1])
        self.price_sum += self.price[n - 1]
        print('주문 음료', self.temp, self.menu[n-1], ':', self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과 출력

        # 추가 주문 또는 지불
        while n != 0: # 지불을 선택하기 전까지 반복하기
            print()
            n = int(input('추가 주문은 음료 번호를, 지불은 0을 누르세요: ')) # 추가주문 또는 지불
            if n > 0 and n < len(self.menu) + 1:
                # 추가 주문 음료 온도
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        self.temp = "HOT"
                    elif t == 2:
                        self.temp = "ICE"
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")


                self.order_price.append(self.price[n-1]) # 가격 리스트에 추가
                self.order_menu.append(self.temp + ' ' + self.menu[n-1]) # 주문 리스트에 추가
                self.price_sum += self.price[n-1] # 합계 금액

                print("추가주문 음료", self.temp, self.menu[n-1], ':', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')

            else:
                if n == 0:
                    print('주문이 완료되었습니다.')
                    print(self.order_menu, self.order_price) # 확인을 위한 리스트 출력
                else:
                    print('없는 메뉴입니다.')

            # 지불 메서드
    def pay(self):
        print(f'총 합계 금액은 {self.price_sum}원 입니다.')
        # 지불 방법
        self.pay_method = 0

        while self.pay_method != 1 and self.pay_method !=2:
            self.pay_method = int(input('현금결제는 1번, 카드 결제는 2번을 입력해 주세요. : '))
            if self.pay_method == 1:
                print('직원을 호출하겠습니다.')
            elif self.pay_method == 2:
                print('IC칩 방향에 맞게 카드를 꽂아주세요.')
            else:
                print('다시 결제를 시도해 주세요.')


    def table(self):
        # 외곽
        outline1 = '⟝' + '-' * 30 + '⟞'
        outline2 = '|' + ' ' * 31 + '|'

        # 외곽 출력
        print(outline1)
        for i in range(5):
            print(outline2)

        # 주문 상품명: 해당 금액
        for i in range(len(self.order_menu)):
            print(self.order_menu[i], ':', self.order_price[i])

        # 합계 금액
        print('합계 금액 : ', self.price_sum)

        # 외곽 출력
        for i in range(5):
            print(outline2)
        print(outline1)

# %%
a = Kiosk()  # 객체 생성 
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료 번호를 입력하세요 :  6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# 주문 음료 ICE choco_latte : 3000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요:  1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  1
# 추가주문 음료 HOT americano : 2000 원
#  합계 :  5000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요:  6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  1
# 추가주문 음료 HOT choco_latte : 3000 원
#  합계 :  8000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요:  3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  1
# 추가주문 음료 HOT mocha : 3000 원
#  합계 :  11000 원
# 추가 주문은 음료 번호를, 지불은 0을 누르세요:  0
# 주문이 완료되었습니다.
# ['ICE choco_latte', 'HOT americano', 'HOT choco_latte', 'HOT mocha'] [3000, 2000, 3000, 3000]
# 총 합계 금액은 11000원 입니다.
# 현금결제는 1번, 카드 결제는 2번을 입력해 주세요. :  2
# IC칩 방향에 맞게 카드를 꽂아주세요.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE choco_latte : 3000
# HOT americano : 2000
# HOT choco_latte : 3000
# HOT mocha : 3000
# 합계 금액 :  11000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
